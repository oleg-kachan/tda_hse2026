# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import random

import numpy as np
import networkx as nx

import sys 
sys.path.append("../lecture6/")
from simplicialx.simplicial import SimplicialComplex

from tqdm import tqdm

# %% [markdown]
# # Homework 2
#
# ## Simplicial network science
#
# Consider `contact-high-school` higher-order network $K$. The dataset is comprised of high school students [interactions](data/contact-high-school.txt) up to 5 people. Students are divided in 3 [groups](data/contact-high-school-nodes-groups.txt), with intra- and inter-group interactions possible.
#
# **(1 point)** Use the `SimplicialX` library to model the interaction network as a simplicial complex, with simplices correponding to student interactions. Perform basic analysis by computing the dimension, f-vector, and the Euler characteristic of a complex. Compute higher-order degrees of vertices relative to edges, triangles, and 3-simplices. Compute higher-order degrees of edges relative to vertices, triangles, and 3-simplices. Compute betweenness or closeness centrality for a chosen pair of simplices of dimensions $p \neq q$. Compute the number of (0,p)-connected components for $p = 1, ..., \dim(K)$. Compute the  vertex orbit degrees for the simplet decompostion of all three-vertex simplets.
#
# **(1 point)** Plot the 1-skeleton of the higher-order network using the `NetworkX` library. In a series of plots visualize computed vertex orbit degrees, vertex and edge higher-order degrees and centralities for a single student group of your choice, highlighting higher feature values with increased vertex size, edge width and/or color intensity. Provide lists of top 10 simplices with the highest values of computed features. Provide rank correlations between all pairs of vertex and edge features, conclude.

# %%
# your code here

# %% [markdown]
# ## Higher-order Laplacian and Hodge decomposition
#
# Consider the 2-dimensional clique complex $L(G)$ of the connected part of the `C.elegans connectome` network $G$, comprised of 279 vertices and 2287 edges. Vertices of $G$ belong to 3 functional groups of motor-, inter-, and sensory neurons.

# %%
A = np.load("../hw2/data/c.elegans_adjacency.npy")
groups = np.load("../hw2/data/c.elegans_groups.npy")

A.shape, groups.shape

# %% [markdown]
# **(1 point)** Use the `SimplicialX` library to get matrices for its oriented boundary operators $\partial_{1}: C_1 \rightarrow C_0$ and $\partial_{2}: C_2 \rightarrow C_1$. Use `numpy` to compute the Laplacian matrices $\mathbf{L}_0$ and $\mathbf{L}_1$ by formulas provided in the Lecture and Seminar 7. Compute the numbers of connected components and cycles in the complex using the eigendecomposition of Laplacian matrices, relate them to Betti numbers.
#
# **(1 points)** Compute the persistent Laplacians $\mathbf{L}_*(K \subset L)$ of $L$ relative to its subcomplex $K$, consisting of a) vertices only, b) vertex-induced subgraph/subcomplex using vertices from a functional group of your choice. Using formulas provided in Lecture and Seminar 7 compute the persistent Betti numbers $\beta_*(K \subset L)$.
#
# **(1 points)** Consider an arbitrary constant function on edges of $K$. Compute its Hodge decomposition to gradient, harmonic, and solenoidal components using formulas provided in Lecture and Seminar 8. Check the validity of solutions by testing where they lie in the kernel of the upper, lower, and full Laplacian operators. Visualize the decomposition, highlighting higher absolute components values with increased edge width and/or color intensity.

# %%
# your code here
